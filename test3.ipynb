# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
import pandas as pd
import time
import datetime
from urllib.request import urlopen

# %%
url = 'https://www.yogiyo.co.kr/mobile/#/326356/'
driver = webdriver.Chrome('/Users/jijoonghong/Downloads/chromedriver')
driver.get(url)
time.sleep(3)
review = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/ul/li[2]/a')
driver.execute_script("arguments[0].click();", review)
store_name = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/div[1]/div[1]/span').text
print(store_name)
# Out:
# 네네치킨-종로점

# %%
try:
    num_of_review = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/div[5]/div[2]/div/strong[1]')
    if num_of_review == '':
        num_of_review = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/ul/li[2]/a/span')
except:
    time.sleep(3)
    num_of_review = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/div[5]/div[2]/div/strong[1]')
    if num_of_review == '':
        num_of_review = driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/ul/li[2]/a/span')
    print("???")

j = 0
idx = 11
time.sleep(3)
print(num_of_review.text)

max_idx = int(num_of_review.text) // 10

while True:
    if j == max_idx:
        print(1)
        break
    #try:
    print(str(j)+"/"+ str(max_idx))
    driver.find_element_by_css_selector('#review > li.list-group-item.btn-more > a').click()
    time.sleep(1.5)

    dates = driver.find_element_by_xpath("// *[ @ id = 'review'] / li["+str(idx)+"] / div[1] / span[2]").text
    if "전" in dates or "어제" in dates or int(dates.split("년")[0]) > 2019 :
        pass
    elif int(dates.split("년")[0]) == 2019 and int(dates.split(" ")[1][:-1]) >= 3:
        pass
    else:
        html = driver.page_source
        print(2)
        break
        #xpath = '//*[@id="review"]/li[' + str(idx) + ']/a'
        #driver.find_element_by_xpath(xpath).click()
    '''
    except:
        time.sleep(3)
        driver.find_element_by_css_selector('#review > li.list-group-item.btn-more > a').click()
        print(driver.find_element_by_xpath("// *[ @ id = 'review'] / li["+str(idx)+"] / div[1] / span[2]").text)

        #xpath = '//*[@id="review"]/li[' + str(idx-10) + ']/a'
        #driver.find_element_by_xpath(xpath).click()
        print('ㅅㅂ')
    '''
    j += 1
    idx += 10
# Out:
# 2801
# 0/280
# 1/280
# 2/280
# 3/280
# 4/280
# 5/280
# 6/280
# 7/280
# 8/280
# 9/280
# 10/280
# 11/280
# 12/280
# 13/280
# 14/280
# 15/280
# 16/280
# 17/280
# 18/280
# 19/280
# 20/280
# 21/280
# 22/280
# 23/280
# 24/280
# 25/280
# 26/280
# 27/280
# 28/280
# 29/280
# 30/280
# 31/280
# 32/280
# 33/280
# 34/280
# 35/280
# 36/280
# 37/280
# 38/280
# 39/280
# 40/280
# 41/280
# 42/280
# 43/280
# 44/280
# 45/280
# 46/280
# 47/280
# 48/280
# 49/280
# 50/280
# 51/280
# 52/280
# 53/280
# 54/280
# 55/280
# 56/280
# 57/280
# 58/280
# 59/280
# 60/280
# 61/280
# 62/280
# 63/280
# 64/280
# 65/280
# 66/280
# 67/280
# 68/280
# 69/280
# 70/280
# 71/280
# 72/280
# 73/280
# 74/280
# 75/280
# 76/280
# 77/280
# 78/280
# 79/280
# 80/280
# 81/280
# 82/280
# 83/280
# 84/280
# 85/280
# 86/280
# 87/280
# 88/280
# 89/280
# 90/280
# 91/280
# 92/280
# 93/280
# 94/280
# 95/280
# 96/280
# 97/280
# 98/280
# 99/280
# 100/280
# 101/280
# 102/280
# 103/280
# 104/280
# 105/280
# 106/280
# 107/280
# 108/280
# 109/280
# 110/280
# 111/280
# 112/280
# 113/280
# 114/280
# 115/280
# 116/280
# 117/280
# 118/280
# 119/280
# 120/280
# 121/280
# 122/280
# 123/280
# 124/280
# 125/280
# 126/280
# 127/280
# 128/280
# 129/280
# 130/280
# 131/280
# 132/280
# 133/280
# 134/280
# 135/280
# 136/280
# 137/280
# 138/280
# 139/280
# 140/280
# 141/280
# 142/280
# 143/280
# 144/280
# 145/280
# 146/280
# 147/280
# 148/280
# 149/280
# 150/280
# 151/280
# 152/280
# 153/280
# 154/280
# 155/280
# 156/280
# 157/280
# 158/280
# 159/280
# 160/280
# 161/280
# 162/280
# 163/280
# 164/280
# 165/280
# 166/280
# 167/280
# 168/280
# 169/280
# 170/280
# 171/280
# 172/280
# 173/280
# 174/280
# 175/280
# 176/280
# 177/280
# 178/280
# 179/280
# 180/280
# 181/280
# 182/280
# 183/280
# 184/280
# 185/280
# 186/280
# 187/280
# 188/280
# 189/280
# 190/280
# 191/280
# 192/280
# 193/280
# 194/280
# 195/280
# 196/280
# 197/280
# 198/280
# 199/280
# 200/280
# 201/280
# 202/280
# 203/280
# 204/280
# 205/280
# 206/280
# 207/280
# 208/280
# 209/280
# 210/280
# 211/280
# 212/280
# 213/280
# 214/280
# 215/280
# 216/280
# 217/280
# 218/280
# 219/280
# 220/280
# 221/280
# 222/280
# 223/280
# 224/280
# 225/280
# 226/280
# 227/280
# 228/280
# 229/280
# 230/280
# 231/280
# 232/280
# 233/280
# 234/280
# 235/280
# 236/280
# 237/280
# 238/280
# 239/280
# 240/280
# 241/280
# 242/280
# 243/280
# 244/280
# 245/280
# 246/280
# 247/280
# 248/280
# 249/280
# 250/280
# 251/280
# 252/280
# 253/280
# 254/280
# 255/280
# 256/280
# 257/280
# 258/280
# 259/280
# 260/280
# 261/280
# 262/280
# 263/280
# 264/280
# 265/280
# 266/280
# 267/280
# 268/280
# 269/280
# 270/280
# 271/280
# 272/280
# 273/280
# 274/280
# 275/280
# 276/280
# 277/280
# 278/280
# 279/280
# 1

# %%
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.find_all(class_='list-group-item star-point ng-scope')

# %%
print(reviews[0])
#store_name = review.find(class_ = "restaurant-name ng-binding").get_text()
# Out:
# <li class="list-group-item star-point ng-scope" ng-repeat="review in restaurant.reviews" on-finish-render="scrollCartArea()">
# <div>
# <span class="review-id ng-binding" ng-show="review.phone">pe**님</span>
# <span class="review-time ng-binding" ng-bind="review.time|since">22시간 전</span>
# <a class="btn-report" href="" ng-click="report_reply(review.id, 'user', review)">신고</a>
# </div>
# <div>
# <div class="star-point">
# <span class="total">
# <!-- ngRepeat: i in review.rating|number_to_array track by $index --><span class="full ng-scope" ng-repeat="i in review.rating|number_to_array track by $index">★</span><!-- end ngRepeat: i in review.rating|number_to_array track by $index --><span class="full ng-scope" ng-repeat="i in review.rating|number_to_array track by $index">★</span><!-- end ngRepeat: i in review.rating|number_to_array track by $index --><span class="full ng-scope" ng-repeat="i in review.rating|number_to_array track by $index">★</span><!-- end ngRepeat: i in review.rating|number_to_array track by $index --><span class="full ng-scope" ng-repeat="i in review.rating|number_to_array track by $index">★</span><!-- end ngRepeat: i in review.rating|number_to_array track by $index --><span class="full ng-scope" ng-repeat="i in review.rating|number_to_array track by $index">★</span><!-- end ngRepeat: i in review.rating|number_to_array track by $index --><!-- ngRepeat: i in (5.9 - (review.rating|number:1))|number_to_array track by $index -->
# </span>
# <span class="category" ng-show="review.rating_taste &gt; 0 || review.rating_quantity &gt; 0 || review.rating_delivery &gt; 0">
# <span class="category-tit" ng-show="review.rating_taste &gt; 0">맛</span>
# <span class="full" ng-show="review.rating_taste &gt; 0">★</span>
# <span class="points ng-binding" ng-show="review.rating_taste &gt; 0">4</span>
# <span class="category-tit" ng-show="review.rating_quantity &gt; 0">양</span>
# <span class="full" ng-show="review.rating_quantity &gt; 0">★</span>
# <span class="points ng-binding" ng-show="review.rating_quantity &gt; 0">5</span>
# <span class="category-tit" ng-show="review.rating_delivery &gt; 0">배달</span>
# <span class="full" ng-show="review.rating_delivery &gt; 0">★</span>
# <span class="points ng-binding" ng-show="review.rating_delivery &gt; 0">4</span>
# </span>
# </div>
# </div>
# <!-- one image layout -->
# <!-- ngIf: review.review_images.length == 1 --><table class="info-images ng-scope" ng-if="review.review_images.length == 1" style="width: 628px;">
# <tbody><tr>
# <td>
# <div style="width: 628px; height: 314px;">
# <img class="ng-isolate-scope" data-index="0" data-url="https://rev-static.yogiyo.co.kr/2520a6175897df516fbe15eca7d321cb.jpg" ng-click="restaurant_image_view($event)" ng-error-and-load="error_load_image($event)" ng-src="https://rev-static.yogiyo.co.kr/2520a6175897df516fbe15eca7d321cb_tn.jpg" src="https://rev-static.yogiyo.co.kr/2520a6175897df516fbe15eca7d321cb_tn.jpg" style="width: 628px; height: 837.006px; left: 0px; top: -261.5px; visibility: visible;"/>
# </div>
# </td>
# </tr>
# </tbody></table><!-- end ngIf: review.review_images.length == 1 -->
# <!-- two image layout -->
# <!-- ngIf: review.review_images.length == 2 -->
# <!-- three image layout -->
# <!-- ngIf: review.review_images.length == 3 -->
# <div class="order-items default ng-binding" ng-click="show_review_menu($event)">
#             순살 반반/1(반마리 선택(순살양념반,순살후라이드반))
#           </div>
# <p class="ng-binding" ng-bind-html="review.comment|strip_html" ng-show="review.comment">양이 넉넉합니다. 둘이먹기에도 넉넉.</p>
# <!-- ngIf: !!review.owner_reply --><div class="review-answer ng-scope" ng-if="!!review.owner_reply">
# <div>
# <span class="owner-review-id">사장님</span>
# <span class="review-time ng-binding" ng-bind="review.owner_reply.created_at|since">21시간 전</span>
# <a class="btn-report" href="" ng-click="report_reply(review.owner_reply.id, 'owner', review)">신고</a>
# </div>
# <p class="ng-binding" ng-bind-html="review.owner_reply.comment|strip_html">만족을 드리지 못해 죄송합니다.
# 다음에는 별5개 받을 수 있도록 더 노력하는 종로점이 되겠습니다.</p>
# </div><!-- end ngIf: !!review.owner_reply -->
# </li>

# %%
j = 0
idx = 11
print(int(num_of_review.text))
if int(num_of_review.text) < 10:
    driver.back()
    continue
max_idx = int(num_of_review.text) // 10

while True:
    if j == max_idx:
        html = driver.page_source
        break
    try:
        k = len(driver.find_elemnents_by_css_selector('//*[@id="review"]>li.list-group-item star-point ng-scope'))
        print(k)
        print(idx)
        driver.find_element_by_css_selector('#review > li.list-group-item.btn-more > a').click()
        time.sleep(1.5)
        dates = driver.find_element_by_xpath('// *[ @ id = "review"] / li['+str(idx)+'] / div[1] / span[2]').text
        if "전" in dates or "어제" in dates or (int(dates.split("년")[0]) >= 2019 and int(dates.split(" ")[1][0]) >= 3):
            pass
        else:
            html = driver.page_source
            break

    except Exception as e:
        print(e)
        time.sleep(3)
        driver.find_element_by_css_selector('#review > li.list-group-item.btn-more > a').click()
        time.sleep(1.5)
        dates = driver.find_element_by_xpath('// *[ @ id = "review"] / li[' + str(idx) + '] / div[1] / span[2]').text
        if "전" in dates or "어제" in dates or (
                int(dates.split("년")[0]) >= 2019 and int(dates.split(" ")[1][0]) >= 3):
            pass
        else:
            html = driver.page_source
            break
    j += 1
    idx += 10
