# %%
import pandas as pd

# %%
df = pd.read_csv("./중구_종합.csv")

# %%
len(df)
# Out:
# 44999

# %%
df2 = df.drop_duplicates(subset = ["가게명", "리뷰 내용"])

# %%
len(df2)
# Out:
# 22226

# %%
df2.tail(50)
# Out:
#        Unnamed: 0  Unnamed: 0.1      시   구    업종명            가게명     년  월  \
# 44904        3650             0  서울특별시  중구  편의점마트      계경순대국-동묘점  2021  4
# 44905        3651             0  서울특별시  중구  편의점마트      계경순대국-동묘점  2021  4
# 44906        3652             0  서울특별시  중구  편의점마트      계경순대국-동묘점  2021  4
# 44907        3653             0  서울특별시  중구  편의점마트      계경순대국-동묘점  2021  3
# 44908        3654             0  서울특별시  중구  편의점마트      계경순대국-동묘점  2021  3
# 44909        3655             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  7
# 44910        3656             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  7
# 44911        3657             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  7
# 44912        3658             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  5
# 44913        3659             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  5
# 44914        3660             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  4
# 44915        3661             0  서울특별시  중구  편의점마트  이삭토스트-을지로4가역점  2021  4
# ...

# %%
df2.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-40948bba9835> in <module>
# ----> 1 df2.tail()
#
# NameError: name 'df2' is not defined
